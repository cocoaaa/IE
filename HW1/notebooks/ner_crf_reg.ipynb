# %% [markdown]
# # Part 1: NER with CRF
# - author: Hayley Song

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import chain

import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, cross_val_predict

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

import joblib
import eli5

from datetime import datetime

# %%
sys.path
# Out:
# ['..',
#  '..',
#  '',
#  '/home/hayley/miniconda3/envs/fastai/lib/python36.zip',
#  '/home/hayley/miniconda3/envs/fastai/lib/python3.6',
#  '/home/hayley/miniconda3/envs/fastai/lib/python3.6/lib-dynload',
#  '/home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages',
#  '/home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/defusedxml-0.5.0-py3.6.egg',
#  '/home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/IPython/extensions',
#  '/home/hayley/.ipython']

# %%
sys.path.insert(0, "..")

# %%
from nlp_utils import data_converter, conlleval

# %% [markdown]
# Load train data in IOB scheme and load train and dev data after changing it to the BIO scheme.

# %%
# train_data_iob = data_converter.read_conll('../data/eng.train')[1:] #ignore header
train_data_bio = data_converter.read_conll('../nlp_utils/train.bio')[1:] #ignore header
dev_data_bio = data_converter.read_conll('../nlp_utils/testa.bio')[1:]
test_data = data_converter.read_conll('../data/eng.testb')[1:]

# %%
# print(train_data_iob[0])
print("="*50)
print("train data")
print(train_data_bio[0])
print("="*50)
print("dev data")
print(dev_data_bio[0])
print("="*50)
print("test data")
print(test_data[0])
# Out:
# ==================================================
# train data
# [['EU', 'NNP', 'I-NP', 'I-ORG', 'B-ORG'], ['rejects', 'VBZ', 'I-VP', 'O', 'O'], ['German', 'JJ', 'I-NP', 'I-MISC', 'B-MISC'], ['call', 'NN', 'I-NP', 'O', 'O'], ['to', 'TO', 'I-VP', 'O', 'O'], ['boycott', 'VB', 'I-VP', 'O', 'O'], ['British', 'JJ', 'I-NP', 'I-MISC', 'B-MISC'], ['lamb', 'NN', 'I-NP', 'O', 'O'], ['.', '.', 'O', 'O', 'O']]
# ==================================================
# dev data
# [['CRICKET', 'NNP', 'I-NP', 'O', 'O'], ['-', ':', 'O', 'O', 'O'], ['LEICESTERSHIRE', 'NNP', 'I-NP', 'I-ORG', 'B-ORG'], ['TAKE', 'NNP', 'I-NP', 'O', 'O'], ['OVER', 'IN', 'I-PP', 'O', 'O'], ['AT', 'NNP', 'I-NP', 'O', 'O'], ['TOP', 'NNP', 'I-NP', 'O', 'O'], ['AFTER', 'NNP', 'I-NP', 'O', 'O'], ['INNINGS', 'NNP', 'I-NP', 'O', 'O'], ['VICTORY', 'NN', 'I-NP', 'O', 'O'], ['.', '.', 'O', 'O', 'O']]
# ==================================================
# test data
# [['SOCCER', 'NN', 'I-NP'], ['-', ':', 'O'], ['JAPAN', 'NNP', 'I-NP'], ['GET', 'VB', 'I-VP'], ['LUCKY', 'NNP', 'I-NP'], ['WIN', 'NNP', 'I-NP'], [',', ',', 'O'], ['CHINA', 'NNP', 'I-NP'], ['IN', 'IN', 'I-PP'], ['SURPRISE', 'DT', 'I-NP'], ['DEFEAT', 'NN', 'I-NP'], ['.', '.', 'O']]

# %%
# sentence lengths
lengths = [len(sent) for sent in train_data_bio]
f, ax = plt.subplots()
ax.scatter(range(len(train_data_bio)), lengths)
print(f"Avg. sentence length: {np.mean(lengths)} words")
# Out:
# Avg. sentence length: 13.651117784451118 words

# %%
train_df_iob = pd.read_csv('../data/eng.train', delimiter=' ')
train_df = pd.read_csv('../data/train.bio', delimiter=' ')
dev_df = pd.read_csv('../data/testa.bio', delimiter=' ')

# %%
train_df.head()
# Out:
#   -DOCSTART-  -X-     O     O.1     O.2
# 0         EU  NNP  I-NP   I-ORG   B-ORG
# 1    rejects  VBZ  I-VP       O       O
# 2     German   JJ  I-NP  I-MISC  B-MISC
# 3       call   NN  I-NP       O       O
# 4         to   TO  I-VP       O       O

# %%
dev_df.head()
# Out:
#        -DOCSTART-  -X-     O    O.1    O.2
# 0         CRICKET  NNP  I-NP      O      O
# 1               -    :     O      O      O
# 2  LEICESTERSHIRE  NNP  I-NP  I-ORG  B-ORG
# 3            TAKE  NNP  I-NP      O      O
# 4            OVER   IN  I-PP      O      O

# %% [markdown]
# Change the column names to something more meaningful.

# %%
new_column = ['token', 'pos', 'chunk_tag', 'tag_ibo', 'tag_bio']
rename_dict = dict([kv for kv in zip(dev_df.columns, new_column)])
# do not to run this more than once (it will override the key values)
print(rename_dict)
# Out:
# {'-DOCSTART-': 'token', '-X-': 'pos', 'O': 'chunk_tag', 'O.1': 'tag_ibo', 'O.2': 'tag_bio'}

# %%
train_df.rename(rename_dict, axis='columns', inplace=True)
dev_df.rename(rename_dict, axis='columns', inplace=True)

# %%
print(train_df.head(10))
print("="*50)
print(dev_df.head(10))
# Out:
#      token  pos chunk_tag tag_ibo tag_bio
# 0       EU  NNP      I-NP   I-ORG   B-ORG
# 1  rejects  VBZ      I-VP       O       O
# 2   German   JJ      I-NP  I-MISC  B-MISC
# 3     call   NN      I-NP       O       O
# 4       to   TO      I-VP       O       O
# 5  boycott   VB      I-VP       O       O
# 6  British   JJ      I-NP  I-MISC  B-MISC
# 7     lamb   NN      I-NP       O       O
# 8        .    .         O       O       O
# 9    Peter  NNP      I-NP   I-PER   B-PER
# ==================================================
#             token  pos chunk_tag tag_ibo tag_bio
# 0         CRICKET  NNP      I-NP       O       O
# 1               -    :         O       O       O
# 2  LEICESTERSHIRE  NNP      I-NP   I-ORG   B-ORG
# 3            TAKE  NNP      I-NP       O       O
# 4            OVER   IN      I-PP       O       O
# 5              AT  NNP      I-NP       O       O
# 6             TOP  NNP      I-NP       O       O
# 7           AFTER  NNP      I-NP       O       O
# 8         INNINGS  NNP      I-NP       O       O
# 9         VICTORY   NN      I-NP       O       O

# %%
train_y = train_df['tag_bio']
dev_y = dev_df['tag_bio']

# %%
train_df.columns
# Out:
# Index(['token', 'pos', 'chunk_tag', 'tag_ibo', 'tag_bio'], dtype='object')

# %%
X = train_df[['token', 'pos']]
print(X.head())
# Out:
#      token  pos
# 0       EU  NNP
# 1  rejects  VBZ
# 2   German   JJ
# 3     call   NN
# 4       to   TO

# %% [markdown]
# ## Word to individual feature
# We represent a token/word as a feature vector using the following features:
# word in lowercase, POS, suffix2, suffix3, word shape info, prev_word in lowercase, prev_word_POS, prev_word_shape, next_word in lowercase, next_word_POS, next_word_shape,
# location in the sentence (BOS, EOS)

# %% [markdown]
# ## Improve features with context from neighboring words
# Now, we use each word's vector representation to build a feature for each word using neighboring words.
# We will concatenate previous and next words' features to current word's features for the words in the middle of a sentence. If a word is at the sentence boundary (ie. beginning or end), then we add only the word features that is available.  We will also add two new boolean features, 'bos' and 'eos', that indicates whetehr the word is at the beginning or end of the sentence, repectively.

# %%
def wordInfo2vec(sent, i):
    """
    Make a vector representation of a wordInfo (tuple/list) at the ith position of the input sentence, sent.
    
    Args:
    - sent (list): a list of word information. 
    A word information is a list of [word, POS, chunk_tag, tag_ibo, tag_bio]
    - i (int): index into the sentence to select a word information
    
    Returns:
    - vec (list): a vector representation of the selected word using the following list of features.
    [word_lowercase, POS, POS2, last2, last3, isUpper, isTitle, isAlpha, isDigit]
    """
    assert(0 <= i and i < len(sent))
    word_info = sent[i]
    word, pos, *_ = word_info
#     print(f'word: {word}, pos: {pos}')
    
    vec = {
      'word': word.lower(),
      'pos': pos,
      'pos2': pos[:2],
      'last2': word[-2:],
      'last3': word[-3:],
      'isUpper': word.isupper(),
      'isTitle': word.istitle(),
      'isAlpha': word.isalpha(),
      'isDigit': word.isdigit(),
    }
    
          
    if len(sent) == 1:
        vec['bos'] = True
        vec['eos'] = True    
        return vec

    # add next word's context
    if i < len(sent)-1:          
        next_info = sent[i+1]
        next_word, next_pos, *_ = next_info
        vec.update({
            'next_word': next_word,
            'next_pos': next_pos,
            'next_pos2': next_pos[:2],
            'next_last2': next_word[-2:],
            'next_last3': next_word[-3:],
            'next_isUpper': next_word.isupper(),
            'next_isTitle': next_word.istitle(),
            'next_isalpha': next_word.isalpha(),
            'next_isdigit': next_word.isdigit()
        })
    else: 
        vec['eos'] = True

    # add previous word's context
    if i > 0:
        prev_info = sent[i-1]
        prev_word, prev_pos, *_ = prev_info
        vec.update({
            'prev_word': prev_word,
            'prev_pos': prev_pos,
            'prev_pos2': prev_pos[:2],
            'prev_last2': prev_word[-2:],
            'prev_last3': prev_word[-3:],
            'prev_isUpper': prev_word.isupper(),
            'prev_isTitle': prev_word.istitle(),
            'prev_isalpha': prev_word.isalpha(),
            'prev_isdigit': prev_word.isdigit()
        })
    else:
        vec['bos'] = True
      
    return vec

def test0_wordInfo2vec():
    wordInfo = train_data_bio[1][0]
    sent = [wordInfo]
    print(f"word info: {wordInfo}")
    print(f"vec: {wordInfo2vec(sent, 0)}")

def test_wordInfo2vec():
    sent = train_data_bio[1]
    for i in range(len(sent)):
        print("="*80)
        print(f"word info: {sent[i]}")
        vec = wordInfo2vec(sent, i)
        print(f"vec: {vec}")

test0_wordInfo2vec()
#test_wordInfo2vec()
# Out:
# word info: ['Peter', 'NNP', 'I-NP', 'I-PER', 'B-PER']
# vec: {'word': 'peter', 'pos': 'NNP', 'pos2': 'NN', 'last2': 'er', 'last3': 'ter', 'isUpper': False, 'isTitle': True, 'isAlpha': True, 'isDigit': False, 'bos': True, 'eos': True}

# %%
def sent2vecs(sent):
    return [wordInfo2vec(sent, i) for i in range(len(sent))]

def test_sent2vecs():
    sent = train_data_bio[5]
    vecs = sent2vecs(sent)
    for vec in vecs:
        print("="*80)
        print(vec)
        
# test_sent2vecs();
# Out:
# ================================================================================
# {'word': '"', 'pos': '"', 'pos2': '"', 'last2': '"', 'last3': '"', 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': 'We', 'next_pos': 'PRP', 'next_pos2': 'PR', 'next_last2': 'We', 'next_last3': 'We', 'next_isUpper': False, 'next_isTitle': True, 'next_isalpha': True, 'next_isdigit': False, 'bos': True}
# ================================================================================
# {'word': 'we', 'pos': 'PRP', 'pos2': 'PR', 'last2': 'We', 'last3': 'We', 'isUpper': False, 'isTitle': True, 'isAlpha': True, 'isDigit': False, 'next_word': 'do', 'next_pos': 'VBP', 'next_pos2': 'VB', 'next_last2': 'do', 'next_last3': 'do', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': '"', 'prev_pos': '"', 'prev_pos2': '"', 'prev_last2': '"', 'prev_last3': '"', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'do', 'pos': 'VBP', 'pos2': 'VB', 'last2': 'do', 'last3': 'do', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': "n't", 'next_pos': 'RB', 'next_pos2': 'RB', 'next_last2': "'t", 'next_last3': "n't", 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'We', 'prev_pos': 'PRP', 'prev_pos2': 'PR', 'prev_last2': 'We', 'prev_last3': 'We', 'prev_isUpper': False, 'prev_isTitle': True, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': "n't", 'pos': 'RB', 'pos2': 'RB', 'last2': "'t", 'last3': "n't", 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': 'support', 'next_pos': 'VB', 'next_pos2': 'VB', 'next_last2': 'rt', 'next_last3': 'ort', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'do', 'prev_pos': 'VBP', 'prev_pos2': 'VB', 'prev_last2': 'do', 'prev_last3': 'do', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'support', 'pos': 'VB', 'pos2': 'VB', 'last2': 'rt', 'last3': 'ort', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'any', 'next_pos': 'DT', 'next_pos2': 'DT', 'next_last2': 'ny', 'next_last3': 'any', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': "n't", 'prev_pos': 'RB', 'prev_pos2': 'RB', 'prev_last2': "'t", 'prev_last3': "n't", 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'any', 'pos': 'DT', 'pos2': 'DT', 'last2': 'ny', 'last3': 'any', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'such', 'next_pos': 'JJ', 'next_pos2': 'JJ', 'next_last2': 'ch', 'next_last3': 'uch', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'support', 'prev_pos': 'VB', 'prev_pos2': 'VB', 'prev_last2': 'rt', 'prev_last3': 'ort', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'such', 'pos': 'JJ', 'pos2': 'JJ', 'last2': 'ch', 'last3': 'uch', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'recommendation', 'next_pos': 'NN', 'next_pos2': 'NN', 'next_last2': 'on', 'next_last3': 'ion', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'any', 'prev_pos': 'DT', 'prev_pos2': 'DT', 'prev_last2': 'ny', 'prev_last3': 'any', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'recommendation', 'pos': 'NN', 'pos2': 'NN', 'last2': 'on', 'last3': 'ion', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'because', 'next_pos': 'IN', 'next_pos2': 'IN', 'next_last2': 'se', 'next_last3': 'use', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'such', 'prev_pos': 'JJ', 'prev_pos2': 'JJ', 'prev_last2': 'ch', 'prev_last3': 'uch', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'because', 'pos': 'IN', 'pos2': 'IN', 'last2': 'se', 'last3': 'use', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'we', 'next_pos': 'PRP', 'next_pos2': 'PR', 'next_last2': 'we', 'next_last3': 'we', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'recommendation', 'prev_pos': 'NN', 'prev_pos2': 'NN', 'prev_last2': 'on', 'prev_last3': 'ion', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'we', 'pos': 'PRP', 'pos2': 'PR', 'last2': 'we', 'last3': 'we', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'do', 'next_pos': 'VBP', 'next_pos2': 'VB', 'next_last2': 'do', 'next_last3': 'do', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'because', 'prev_pos': 'IN', 'prev_pos2': 'IN', 'prev_last2': 'se', 'prev_last3': 'use', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'do', 'pos': 'VBP', 'pos2': 'VB', 'last2': 'do', 'last3': 'do', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': "n't", 'next_pos': 'RB', 'next_pos2': 'RB', 'next_last2': "'t", 'next_last3': "n't", 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'we', 'prev_pos': 'PRP', 'prev_pos2': 'PR', 'prev_last2': 'we', 'prev_last3': 'we', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': "n't", 'pos': 'RB', 'pos2': 'RB', 'last2': "'t", 'last3': "n't", 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': 'see', 'next_pos': 'VB', 'next_pos2': 'VB', 'next_last2': 'ee', 'next_last3': 'see', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'do', 'prev_pos': 'VBP', 'prev_pos2': 'VB', 'prev_last2': 'do', 'prev_last3': 'do', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'see', 'pos': 'VB', 'pos2': 'VB', 'last2': 'ee', 'last3': 'see', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'any', 'next_pos': 'DT', 'next_pos2': 'DT', 'next_last2': 'ny', 'next_last3': 'any', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': "n't", 'prev_pos': 'RB', 'prev_pos2': 'RB', 'prev_last2': "'t", 'prev_last3': "n't", 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'any', 'pos': 'DT', 'pos2': 'DT', 'last2': 'ny', 'last3': 'any', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'grounds', 'next_pos': 'NNS', 'next_pos2': 'NN', 'next_last2': 'ds', 'next_last3': 'nds', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'see', 'prev_pos': 'VB', 'prev_pos2': 'VB', 'prev_last2': 'ee', 'prev_last3': 'see', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'grounds', 'pos': 'NNS', 'pos2': 'NN', 'last2': 'ds', 'last3': 'nds', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'for', 'next_pos': 'IN', 'next_pos2': 'IN', 'next_last2': 'or', 'next_last3': 'for', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'any', 'prev_pos': 'DT', 'prev_pos2': 'DT', 'prev_last2': 'ny', 'prev_last3': 'any', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'for', 'pos': 'IN', 'pos2': 'IN', 'last2': 'or', 'last3': 'for', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'it', 'next_pos': 'PRP', 'next_pos2': 'PR', 'next_last2': 'it', 'next_last3': 'it', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'grounds', 'prev_pos': 'NNS', 'prev_pos2': 'NN', 'prev_last2': 'ds', 'prev_last3': 'nds', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'it', 'pos': 'PRP', 'pos2': 'PR', 'last2': 'it', 'last3': 'it', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': ',', 'next_pos': ',', 'next_pos2': ',', 'next_last2': ',', 'next_last3': ',', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'for', 'prev_pos': 'IN', 'prev_pos2': 'IN', 'prev_last2': 'or', 'prev_last3': 'for', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': ',', 'pos': ',', 'pos2': ',', 'last2': ',', 'last3': ',', 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': '"', 'next_pos': '"', 'next_pos2': '"', 'next_last2': '"', 'next_last3': '"', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'it', 'prev_pos': 'PRP', 'prev_pos2': 'PR', 'prev_last2': 'it', 'prev_last3': 'it', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': '"', 'pos': '"', 'pos2': '"', 'last2': '"', 'last3': '"', 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': 'the', 'next_pos': 'DT', 'next_pos2': 'DT', 'next_last2': 'he', 'next_last3': 'the', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': ',', 'prev_pos': ',', 'prev_pos2': ',', 'prev_last2': ',', 'prev_last3': ',', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'the', 'pos': 'DT', 'pos2': 'DT', 'last2': 'he', 'last3': 'the', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'Commission', 'next_pos': 'NNP', 'next_pos2': 'NN', 'next_last2': 'on', 'next_last3': 'ion', 'next_isUpper': False, 'next_isTitle': True, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': '"', 'prev_pos': '"', 'prev_pos2': '"', 'prev_last2': '"', 'prev_last3': '"', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'commission', 'pos': 'NNP', 'pos2': 'NN', 'last2': 'on', 'last3': 'ion', 'isUpper': False, 'isTitle': True, 'isAlpha': True, 'isDigit': False, 'next_word': "'s", 'next_pos': 'POS', 'next_pos2': 'PO', 'next_last2': "'s", 'next_last3': "'s", 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'the', 'prev_pos': 'DT', 'prev_pos2': 'DT', 'prev_last2': 'he', 'prev_last3': 'the', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': "'s", 'pos': 'POS', 'pos2': 'PO', 'last2': "'s", 'last3': "'s", 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'next_word': 'chief', 'next_pos': 'JJ', 'next_pos2': 'JJ', 'next_last2': 'ef', 'next_last3': 'ief', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'Commission', 'prev_pos': 'NNP', 'prev_pos2': 'NN', 'prev_last2': 'on', 'prev_last3': 'ion', 'prev_isUpper': False, 'prev_isTitle': True, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'chief', 'pos': 'JJ', 'pos2': 'JJ', 'last2': 'ef', 'last3': 'ief', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'spokesman', 'next_pos': 'NN', 'next_pos2': 'NN', 'next_last2': 'an', 'next_last3': 'man', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': "'s", 'prev_pos': 'POS', 'prev_pos2': 'PO', 'prev_last2': "'s", 'prev_last3': "'s", 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': False, 'prev_isdigit': False}
# ================================================================================
# {'word': 'spokesman', 'pos': 'NN', 'pos2': 'NN', 'last2': 'an', 'last3': 'man', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'Nikolaus', 'next_pos': 'NNP', 'next_pos2': 'NN', 'next_last2': 'us', 'next_last3': 'aus', 'next_isUpper': False, 'next_isTitle': True, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'chief', 'prev_pos': 'JJ', 'prev_pos2': 'JJ', 'prev_last2': 'ef', 'prev_last3': 'ief', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'nikolaus', 'pos': 'NNP', 'pos2': 'NN', 'last2': 'us', 'last3': 'aus', 'isUpper': False, 'isTitle': True, 'isAlpha': True, 'isDigit': False, 'next_word': 'van', 'next_pos': 'NNP', 'next_pos2': 'NN', 'next_last2': 'an', 'next_last3': 'van', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'spokesman', 'prev_pos': 'NN', 'prev_pos2': 'NN', 'prev_last2': 'an', 'prev_last3': 'man', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'van', 'pos': 'NNP', 'pos2': 'NN', 'last2': 'an', 'last3': 'van', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'der', 'next_pos': 'FW', 'next_pos2': 'FW', 'next_last2': 'er', 'next_last3': 'der', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'Nikolaus', 'prev_pos': 'NNP', 'prev_pos2': 'NN', 'prev_last2': 'us', 'prev_last3': 'aus', 'prev_isUpper': False, 'prev_isTitle': True, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'der', 'pos': 'FW', 'pos2': 'FW', 'last2': 'er', 'last3': 'der', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'Pas', 'next_pos': 'NNP', 'next_pos2': 'NN', 'next_last2': 'as', 'next_last3': 'Pas', 'next_isUpper': False, 'next_isTitle': True, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'van', 'prev_pos': 'NNP', 'prev_pos2': 'NN', 'prev_last2': 'an', 'prev_last3': 'van', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'pas', 'pos': 'NNP', 'pos2': 'NN', 'last2': 'as', 'last3': 'Pas', 'isUpper': False, 'isTitle': True, 'isAlpha': True, 'isDigit': False, 'next_word': 'told', 'next_pos': 'VBD', 'next_pos2': 'VB', 'next_last2': 'ld', 'next_last3': 'old', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'der', 'prev_pos': 'FW', 'prev_pos2': 'FW', 'prev_last2': 'er', 'prev_last3': 'der', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'told', 'pos': 'VBD', 'pos2': 'VB', 'last2': 'ld', 'last3': 'old', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'a', 'next_pos': 'DT', 'next_pos2': 'DT', 'next_last2': 'a', 'next_last3': 'a', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'Pas', 'prev_pos': 'NNP', 'prev_pos2': 'NN', 'prev_last2': 'as', 'prev_last3': 'Pas', 'prev_isUpper': False, 'prev_isTitle': True, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'a', 'pos': 'DT', 'pos2': 'DT', 'last2': 'a', 'last3': 'a', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'news', 'next_pos': 'NN', 'next_pos2': 'NN', 'next_last2': 'ws', 'next_last3': 'ews', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'told', 'prev_pos': 'VBD', 'prev_pos2': 'VB', 'prev_last2': 'ld', 'prev_last3': 'old', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'news', 'pos': 'NN', 'pos2': 'NN', 'last2': 'ws', 'last3': 'ews', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': 'briefing', 'next_pos': 'NN', 'next_pos2': 'NN', 'next_last2': 'ng', 'next_last3': 'ing', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': True, 'next_isdigit': False, 'prev_word': 'a', 'prev_pos': 'DT', 'prev_pos2': 'DT', 'prev_last2': 'a', 'prev_last3': 'a', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': 'briefing', 'pos': 'NN', 'pos2': 'NN', 'last2': 'ng', 'last3': 'ing', 'isUpper': False, 'isTitle': False, 'isAlpha': True, 'isDigit': False, 'next_word': '.', 'next_pos': '.', 'next_pos2': '.', 'next_last2': '.', 'next_last3': '.', 'next_isUpper': False, 'next_isTitle': False, 'next_isalpha': False, 'next_isdigit': False, 'prev_word': 'news', 'prev_pos': 'NN', 'prev_pos2': 'NN', 'prev_last2': 'ws', 'prev_last3': 'ews', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}
# ================================================================================
# {'word': '.', 'pos': '.', 'pos2': '.', 'last2': '.', 'last3': '.', 'isUpper': False, 'isTitle': False, 'isAlpha': False, 'isDigit': False, 'eos': True, 'prev_word': 'briefing', 'prev_pos': 'NN', 'prev_pos2': 'NN', 'prev_last2': 'ng', 'prev_last3': 'ing', 'prev_isUpper': False, 'prev_isTitle': False, 'prev_isalpha': True, 'prev_isdigit': False}

# %%
def sent2labels(sent):
    """
    Create a list of lables for the sentence
    
    Args:
    - sent (list): a list of wordInfos
    """
    return [label for (*_, label) in sent]
def test_sent2labels():
    sent = train_data_bio[1]
    print(sent2labels(sent))
test_sent2labels()
# Out:
# ['B-PER', 'I-PER']

# %% [markdown]
# ## Create train, dev, test data matrix and labels

# %%
# Create datasets with these feature vectors for each word_info
X_train = [sent2vecs(sent) for sent in train_data_bio]
y_train = [sent2labels(sent) for sent in train_data_bio]

# %%
print("n_sentences: ",len(X_train))
print("n_words: ", len([1 for sent in X_train for w in sent]))
print("y_train len: ", len(y_train))
print (y_train[3])
# Out:
# n_sentences:  14985
# n_words:  204562
# y_train len:  14985
# ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
X_dev = [sent2vecs(sent) for sent in dev_data_bio]
y_dev = [sent2labels(sent) for sent in dev_data_bio]

# %%
X_test = [sent2vecs(sent) for sent in test_data]
# remember we need to convert the tags in BIO scheme to IBO scheme before submitting

# %% [markdown]
# ## Train our first crf model

# %%
# Define our CRF model
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=1,
    all_possible_transitions=True
)

# %%
print (f"n_sentences: {np.array(X_train).shape[0]}")
# Out:
# n_sentences: 14985

# %%
# %%time
crf.fit(X_train, y_train)
# Out:
# CPU times: user 9.18 s, sys: 455 ms, total: 9.63 s
# Wall time: 10.9 s
# CRF(algorithm='lbfgs', all_possible_states=None,
#   all_possible_transitions=True, averaging=None, c=None, c1=0.1, c2=0.1,
#   calibration_candidates=None, calibration_eta=None,
#   calibration_max_trials=None, calibration_rate=None,
#   calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#   gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=1,
#   max_linesearch=None, min_freq=None, model_filename=None,
#   num_memories=None, pa_type=None, period=None, trainer_cls=None,
#   variance=None, verbose=False)

# %% [markdown]
# ## Initial evaluation

# %% [markdown]
# We are interested in the entity-level evaluation, so let's exclude entity type 'O' from our evaluations.

# %%
labels = list(crf.classes_); print(labels)
labels.remove('O'); print(labels)
# Out:
# ['B-ORG', 'O', 'B-MISC', 'B-PER', 'I-PER', 'B-LOC', 'I-ORG', 'I-MISC', 'I-LOC']
# ['B-ORG', 'B-MISC', 'B-PER', 'I-PER', 'B-LOC', 'I-ORG', 'I-MISC', 'I-LOC']

# %%
y_pred = crf.predict(X_dev)
metrics.flat_f1_score(y_dev, y_pred,
                      average='weighted', 
                      labels=labels)
# Out:
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.0

# %% [markdown]
# We can inspect performances per entity type

# %%
sorted_labels = sorted(labels, 
                       key=lambda name: name.split('-')[::-1]
                      )
print(sorted_labels)
# Out:
# ['B-LOC', 'I-LOC', 'B-MISC', 'I-MISC', 'B-ORG', 'I-ORG', 'B-PER', 'I-PER']

# %%
print(metrics.flat_classification_report(
    y_dev, y_pred, labels=sorted_labels, digits=3
))
# Out:
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#        B-LOC      0.000     0.000     0.000      1837
#        I-LOC      0.000     0.000     0.000       257
#       B-MISC      0.000     0.000     0.000       922
#       I-MISC      0.000     0.000     0.000       346
#        B-ORG      0.000     0.000     0.000      1340
#        I-ORG      0.000     0.000     0.000       750
#        B-PER      0.000     0.000     0.000      1842
#        I-PER      0.000     0.000     0.000      1307
#
#    micro avg      0.000     0.000     0.000      8601
#    macro avg      0.000     0.000     0.000      8601
# weighted avg      0.000     0.000     0.000      8601

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-LOC</th>
#
#                 <th>I-LOC</th>
#
#                 <th>B-MISC</th>
#
#                 <th>I-MISC</th>
#
#                 <th>B-ORG</th>
#
#                 <th>I-ORG</th>
#
#                 <th>B-PER</th>
#
#                 <th>I-PER</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="O &rArr; O">
#                             0.491
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.56%)" title="O &rArr; B-LOC">
#                             0.011
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="O &rArr; I-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.59%)" title="O &rArr; B-MISC">
#                             0.002
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="O &rArr; I-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.17%)" title="O &rArr; B-ORG">
#                             0.005
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="O &rArr; I-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.67%)" title="O &rArr; B-PER">
#                             0.01
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="O &rArr; I-PER">
#                             -0.008
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.43%)" title="B-LOC &rArr; O">
#                             0.013
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; B-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.23%)" title="B-LOC &rArr; I-LOC">
#                             -0.005
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.85%)" title="B-LOC &rArr; B-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; I-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; B-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; I-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; B-PER">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-LOC &rArr; I-PER">
#                             -0.008
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-LOC</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.21%)" title="I-LOC &rArr; O">
#                             -0.005
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; B-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.88%)" title="I-LOC &rArr; I-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; B-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; I-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; B-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; I-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; B-PER">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="I-LOC &rArr; I-PER">
#                             -0.008
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-MISC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.88%)" title="B-MISC &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-MISC &rArr; B-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-MISC &rArr; I-LOC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.85%)" title="B-MISC &rArr; B-MISC">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.16%)" title="B-MISC &rArr; I-MISC">
#                             -0.005
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.85%)" title="B-MISC &rArr; B-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-MISC &rArr; I-ORG">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.86%)" title="B-MISC &rArr; B-PER">
#                             -0.008
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.84%)" title="B-MISC &rArr; I-PER">
#                             -0.008
#                         </td>

# %% [markdown]
# Let's save this trained model.

# %%
import joblib
def get_current_time():
    now = datetime.now()
    now_str = f"{now.strftime('%m')}_{now.strftime('%d')}_{now.strftime('%H')}_{now.strftime('%M')}"
    return now_str

# %%
joblib.dump(crf, f"../log/trained/crf_c1:0.1_c2:0.1_iter:100_{get_current_time()}.sav")
# Out:
# ['../log/trained/crf_0.1_0.1_100iter_09_25_11_00.sav']

# %% [markdown]
# ## Hyperparameter tuning

# %%
# define fixed parameters and parameters to search
crf_rs = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=500, 
    all_possible_transitions=True
)
# params_space = {
#     'c1': scipy.stats.expon(scale=0.5),
#     'c2': scipy.stats.expon(scale=0.05),
# }

params_space = {
#     'c1': scipy.stats.truncnorm(-1,2,loc=3,scale=3), #first two are supports (as offsets from mean), loc is mean, scale is var
    'c1': scipy.stats.truncnorm(-1.5,2,loc=5,scale=3),
    'c2': scipy.stats.truncnorm(-1, 2 ,loc=2,scale=2)
}
# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# %%
# %%time
# search

rs = RandomizedSearchCV(crf_rs, params_space, 
                        cv=3, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=100, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed: 36.9min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 64.1min finished
# CPU times: user 9min 40s, sys: 45.1 s, total: 10min 25s
# Wall time: 1h 8min 5s

# %%
# Save this random search result
joblib.dump(rs, f'../log/trained/rs2_cv:3_niter:100_{get_current_time()}.sav')
# Out:
# ['../log/trained/rs2_cv:3_niter:100_10_09_12_21.sav']

# %% [markdown]
# ## Inspect random search space and performance

# %%
report = pd.DataFrame(rs.cv_results_)
c1s = report.param_c1
c2s = report.param_c2
scores = report.mean_test_score
# Out:
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/hayley/miniconda3/envs/fastai/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
f,ax = plt.subplots(figsize=(15,15))

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('c1')
ax.set_ylabel('c2')
ax.set_title(f'Random Search on c1,c2: min={min(scores)}, max={max(scores)}')
ax.scatter(c1s, c2s, c=scores, alpha=0.8, edgecolors=[0,0,0])
# plt.colorbar()

# %% [markdown]
# ## Evaluation of the best CV model

# %%
crf_rs = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.8020282577136353, 'c2': 0.9056248251241479}
# best CV score: 0.8191001358419799
# model size: 0.96M

# %%
y_pred_rs = crf_rs.predict(X_dev)
print(metrics.flat_classification_report(
    y_dev, y_pred_rs, labels= sorted_labels, digits=3)
     )
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC      0.879     0.837     0.858      1837
#        I-LOC      0.921     0.767     0.837       257
#       B-MISC      0.901     0.809     0.853       922
#       I-MISC      0.868     0.720     0.787       346
#        B-ORG      0.841     0.769     0.803      1340
#        I-ORG      0.788     0.789     0.789       750
#        B-PER      0.881     0.890     0.885      1842
#        I-PER      0.932     0.950     0.941      1307
#
#    micro avg      0.877     0.841     0.859      8601
#    macro avg      0.876     0.816     0.844      8601
# weighted avg      0.877     0.841     0.858      8601

# %% [markdown]
# Comparing this result with the result from the initial, randomly guessed hyperparameter setting of c1=c2=0.1, we don't actually see a big improvement. Let's further inspect what the classifier learned then. In order to do so, we can inspect the learned transition (state to state, i.e label to label) probability distribution. In addition, we will inspect the probability of a state (ie. label) of this selected model.

# %%
# use eli5 for the model inspection
eli5.show_weights(crf_rs, top=50)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-LOC</th>
#
#                 <th>I-LOC</th>
#
#                 <th>B-MISC</th>
#
#                 <th>I-MISC</th>
#
#                 <th>B-ORG</th>
#
#                 <th>I-ORG</th>
#
#                 <th>B-PER</th>
#
#                 <th>I-PER</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.75%)" title="O &rArr; O">
#                             4.474
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.15%)" title="O &rArr; B-LOC">
#                             2.852
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.52%)" title="O &rArr; I-LOC">
#                             -2.073
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 87.86%)" title="O &rArr; B-MISC">
#                             2.95
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.83%)" title="O &rArr; I-MISC">
#                             -1.975
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.46%)" title="O &rArr; B-ORG">
#                             2.744
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.46%)" title="O &rArr; I-ORG">
#                             -2.412
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.14%)" title="O &rArr; B-PER">
#                             3.939
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.95%)" title="O &rArr; I-PER">
#                             -1.641
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.48%)" title="B-LOC &rArr; O">
#                             0.72
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.66%)" title="B-LOC &rArr; B-LOC">
#                             -0.281
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.88%)" title="B-LOC &rArr; I-LOC">
#                             5.228
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.26%)" title="B-LOC &rArr; B-MISC">
#                             0.054
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.75%)" title="B-LOC &rArr; I-MISC">
#                             -0.89
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.62%)" title="B-LOC &rArr; B-ORG">
#                             -0.687
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.49%)" title="B-LOC &rArr; I-ORG">
#                             -1.21
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.13%)" title="B-LOC &rArr; B-PER">
#                             -1.589
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.48%)" title="B-LOC &rArr; I-PER">
#                             -1.215
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.68%)" title="I-LOC &rArr; O">
#                             0.016
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.77%)" title="I-LOC &rArr; B-LOC">
#                             -0.112
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.72%)" title="I-LOC &rArr; I-LOC">
#                             4.485
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.11%)" title="I-LOC &rArr; I-MISC">
#                             -0.208
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.08%)" title="I-LOC &rArr; B-ORG">
#                             -0.587
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.64%)" title="I-LOC &rArr; I-ORG">
#                             -0.471
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.80%)" title="I-LOC &rArr; B-PER">
#                             -0.88
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.99%)" title="I-LOC &rArr; I-PER">
#                             -0.402
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-MISC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.73%)" title="B-MISC &rArr; O">
#                             0.664
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.75%)" title="B-MISC &rArr; B-LOC">
#                             -0.449
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.97%)" title="B-MISC &rArr; I-LOC">
#                             -0.839
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.84%)" title="B-MISC &rArr; B-MISC">
#                             -0.431
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.90%)" title="B-MISC &rArr; I-MISC">
#                             5.221
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; B-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.86%)" title="B-MISC &rArr; I-ORG">
#                             -1.384
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 98.15%)" title="B-MISC &rArr; B-PER">
#                             0.2
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.59%)" title="B-MISC &rArr; I-PER">
#                             -1.186
#                         </td>

# %% [markdown]
# Let's first take a look at the learned transition matrix. The transition probabilities look reasonable as it shows high probabilities of transitioning from `B-TYPE` to `I-TYPE` (for instance, `B-MISC` to `I-MISC` and `B-ORG` to `I-ORG`.  Conversely, the model learned that it's unlikely to see a beginning tag of a type to be followed by an intermediate tag of a different type: Pr{`B_ORG` -> `t`} are either very close to 0 or negative for any `t` that is not `I-ORG`, and `B-PER` shows the same trend.

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-LOC</th>
#
#                 <th>I-LOC</th>
#
#                 <th>B-MISC</th>
#
#                 <th>I-MISC</th>
#
#                 <th>B-ORG</th>
#
#                 <th>I-ORG</th>
#
#                 <th>B-PER</th>
#
#                 <th>I-PER</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.60%)" title="O &rArr; O">
#                             5.459
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.54%)" title="O &rArr; B-LOC">
#                             3.58
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.62%)" title="O &rArr; I-LOC">
#                             -2.689
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.13%)" title="O &rArr; B-MISC">
#                             3.763
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.17%)" title="O &rArr; I-MISC">
#                             -2.875
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.10%)" title="O &rArr; B-ORG">
#                             3.777
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.28%)" title="O &rArr; I-ORG">
#                             -3.253
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.59%)" title="O &rArr; B-PER">
#                             4.963
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.34%)" title="O &rArr; I-PER">
#                             -2.4
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.52%)" title="B-LOC &rArr; O">
#                             0.934
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.20%)" title="B-LOC &rArr; B-LOC">
#                             -0.08
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.88%)" title="B-LOC &rArr; I-LOC">
#                             6.887
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.16%)" title="B-LOC &rArr; B-MISC">
#                             0.086
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.34%)" title="B-LOC &rArr; I-MISC">
#                             -1.649
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.97%)" title="B-LOC &rArr; B-ORG">
#                             -0.803
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.37%)" title="B-LOC &rArr; I-ORG">
#                             -2.388
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.56%)" title="B-LOC &rArr; B-PER">
#                             -1.931
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.49%)" title="B-LOC &rArr; I-PER">
#                             -1.597
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.56%)" title="I-LOC &rArr; O">
#                             0.392
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.42%)" title="I-LOC &rArr; I-LOC">
#                             6.067
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.62%)" title="I-LOC &rArr; B-MISC">
#                             -0.173
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.44%)" title="I-LOC &rArr; I-MISC">
#                             -0.422
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.26%)" title="I-LOC &rArr; B-ORG">
#                             -1.015
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.04%)" title="I-LOC &rArr; I-ORG">
#                             -1.082
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.54%)" title="I-LOC &rArr; B-PER">
#                             -1.579
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.84%)" title="I-LOC &rArr; I-PER">
#                             -0.569
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-MISC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.64%)" title="B-MISC &rArr; O">
#                             0.9
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.37%)" title="B-MISC &rArr; B-LOC">
#                             -0.438
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.44%)" title="B-MISC &rArr; I-LOC">
#                             -1.613
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.18%)" title="B-MISC &rArr; B-MISC">
#                             -0.482
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.96%)" title="B-MISC &rArr; I-MISC">
#                             6.843
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.90%)" title="B-MISC &rArr; B-ORG">
#                             0.317
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.67%)" title="B-MISC &rArr; I-ORG">
#                             -2.669
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.21%)" title="B-MISC &rArr; B-PER">
#                             0.475
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.96%)" title="B-MISC &rArr; I-PER">
#                             -1.435
#                         </td>

# %% [markdown]
# Unfortuntately, it looks like the CRF just remembering a lot of words. For example for the tag `B-per`, the algorithm remembers ‘president’ ‘obama’. To overcome this issue we can tune the paramters, especially the regularization paramters of the CRF algorithm. The $c_1$ and $c_2$ parameter of the CRF algorithm are the regularization parameters $\lambda_1$ and $\lambda_2$. While c1 weights the $l_{1}$ regularization, the $c_2 $parameter weights the $l_2$ regularization. We know limit the number of features used by enforcing sparsity on the parameter vector  $w$. To do this we increase the $l_1$ regularization parameter $c_1$.

# %% [markdown]
# ## Regularization of the CRF model

# %%
crf_reg = sklearn_crfsuite.CRF(algorithm='lbfgs',
          c1=10,
          c2=0.1,
          max_iterations=1000,
          all_possible_transitions=False)

# %%
# Save this model
joblib.dump(crf_reg, f'crf_c1:100_c2:0.1_{get_current_time()}.sav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-0ba174138cda> in <module>
#       1 # Save this model
# ----> 2 joblib.dump(crf_reg, f'crf_c1:100_c2:0.1_{get_current_time()}.sav')
#
# NameError: name 'crf_reg' is not defined

# %%
crf_reg = joblib.load('../log/trained/crf_c1:100_c2:0.1_09_26_01_27.sav')
reg_train_pred = cross_val_predict(estimator=crf_reg, X=X_train, y=y_train, cv=5)
report = metrics.flat_classification_report(y_pred=reg_train_pred, y_true=y_train)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC       0.76      0.76      0.76      7140
#       B-MISC       0.84      0.63      0.72      3438
#        B-ORG       0.71      0.63      0.67      6319
#        B-PER       0.77      0.79      0.78      6600
#        I-LOC       0.75      0.54      0.63      1157
#       I-MISC       0.70      0.44      0.54      1155
#        I-ORG       0.65      0.69      0.67      3704
#        I-PER       0.82      0.91      0.86      4528
#            O       0.98      0.99      0.99    170521
#
#    micro avg       0.95      0.95      0.95    204562
#    macro avg       0.78      0.71      0.74    204562
# weighted avg       0.95      0.95      0.95    204562

# %%
# %%time
# Train on the entire train data
crf_reg.fit(X_train, y_train)
# Out:
# CPU times: user 3min 57s, sys: 177 ms, total: 3min 57s
# Wall time: 3min 57s
# CRF(algorithm='lbfgs', all_possible_states=None,
#   all_possible_transitions=False, averaging=None, c=None, c1=10, c2=0.1,
#   calibration_candidates=None, calibration_eta=None,
#   calibration_max_trials=None, calibration_rate=None,
#   calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#   gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=1000,
#   max_linesearch=None, min_freq=None, model_filename=None,
#   num_memories=None, pa_type=None, period=None, trainer_cls=None,
#   variance=None, verbose=False)

# %%
# Visualize the weights
eli5.show_weights(crf_reg, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-LOC</th>
#
#                 <th>I-LOC</th>
#
#                 <th>B-MISC</th>
#
#                 <th>I-MISC</th>
#
#                 <th>B-ORG</th>
#
#                 <th>I-ORG</th>
#
#                 <th>B-PER</th>
#
#                 <th>I-PER</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.31%)" title="O &rArr; O">
#                             7.022
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.68%)" title="O &rArr; B-LOC">
#                             6.338
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.27%)" title="O &rArr; B-MISC">
#                             6.047
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 82.89%)" title="O &rArr; B-ORG">
#                             5.749
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="O &rArr; B-PER">
#                             7.183
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="O &rArr; I-PER">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-LOC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.29%)" title="B-LOC &rArr; O">
#                             0.648
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-LOC &rArr; B-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.38%)" title="B-LOC &rArr; I-LOC">
#                             5.514
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 97.91%)" title="B-LOC &rArr; B-MISC">
#                             0.285
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-LOC &rArr; I-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-LOC &rArr; B-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-LOC &rArr; I-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.49%)" title="B-LOC &rArr; B-PER">
#                             -0.371
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-LOC &rArr; I-PER">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-LOC</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; O">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.42%)" title="I-LOC &rArr; I-LOC">
#                             4.573
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; I-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; I-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; B-PER">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="I-LOC &rArr; I-PER">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-MISC</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.37%)" title="B-MISC &rArr; O">
#                             0.628
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; B-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; I-LOC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; B-MISC">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.88%)" title="B-MISC &rArr; I-MISC">
#                             6.24
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; B-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; I-ORG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.62%)" title="B-MISC &rArr; B-PER">
#                             0.567
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B-MISC &rArr; I-PER">
#                             0.0
#                         </td>
#
#                 </tr>

# %% [markdown]
# First of all, notice how setting the parameter $c_1$ for the $l_1$ regularizer drove many weights to be close to zero.  We can see that the regualization is doing the right job of making the weight parameters sparse. To see if this high regualization hyperparameter for $l_1$ term, we further inspect the transition probabilities and the learned weights. Let's focus on the second columns of Table 4 with Table 3. We discussed earlier that the unregularized model memorized specific words word-by-word for deciding whether to output `B-LOC` or not.  All the features with high weights were given to tokens learned from the training dataset, such as "chester-le-street", "gemerny" and "hungary". However, this overfitting is alleviated through increasing the $l_1$ regualization. The regualized model assigns high weights to more generalizable features such as "bos" (i.e. beginning of the sentence), "prev_las2:AT" and "last2:ia". We observe this improvement in generalization for other class weights as well.  Column for `Y=I-ORG` shows high weights for features like `word:co`, `last3:oom`, `next_isDigit` and `word:corp` which are all intuitively reasonable (for instance a lot of companies name starts with `Cooporation...`) and not specific to a single training instance, like "Microsoft". For `I-PER` class, the most significant weights were assigned to features like `last2:er`, `last2:on`, `prev_isUpper` and `pos:NNP`.  These features in fact match the rules how a human would decide whether an entity is of PERSON.

# %% [markdown]
# ## Part 1 prediction
# Now, we make a prediction on the `testb` dataset using this tuned, regulaized CRF model.

# %%
# Predict X_dev
reg_dev_pred = crf_reg.predict(X_dev)

# Evaluate using precision, recall and F-1
print(metrics.flat_classification_report(
     y_dev, reg_dev_pred, labels= sorted_labels, digits=3)
     )
# Out:
#               precision    recall  f1-score   support
#
#        B-LOC      0.793     0.763     0.778      1837
#        I-LOC      0.797     0.564     0.661       257
#       B-MISC      0.859     0.682     0.761       922
#       I-MISC      0.773     0.454     0.572       346
#        B-ORG      0.734     0.647     0.688      1340
#        I-ORG      0.618     0.649     0.633       750
#        B-PER      0.809     0.840     0.825      1842
#        I-PER      0.873     0.921     0.897      1307
#
#    micro avg      0.790     0.749     0.769      8601
#    macro avg      0.782     0.690     0.727      8601
# weighted avg      0.791     0.749     0.766      8601

# %%
# Predict on test
crf_reg = crf_rs
reg_test_pred_bio = crf_reg.predict(X_test)
reg_test_pred_ibo = data_converter.tags_to_conll(reg_test_pred_bio)

# %%
joblib.dump(reg_test_pred_bio,'../report/predictions/crf_rs_bio.sav')
# Out:
# ['../report/predictions/crf_rs_bio.sav']

# %% [markdown]
# ## Processing our predictions for submission

# %%
t = reg_test_pred_bio[96]
t2 = data_converter.tags_to_conll(t)

# %%
print(reg_test_pred_bio[96])
print(reg_test_pred_ibo[96])
# Out:
# ['O', 'O', 'I-LOC', 'I-LOC', 'B-LOC', 'I-LOC', 'O', 'O', 'O']
# ['O', 'O', 'I-LOC', 'I-LOC', 'B-LOC', 'I-LOC', 'O', 'O', 'O']

# %%
print(t2)
# Out:
# ['O', 'O', 'O', 'I-LOC', 'O', 'I-LOC', 'I-LOC', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
import pdb
for i,tags in enumerate(reg_test_pred_bio):
    for t in tags:
        if 'B' in t:
            print(i)
            print(tags)
            pdb.set_trace()
# Out:
# 96
# ['O', 'O', 'I-LOC', 'I-LOC', 'B-LOC', 'I-LOC', 'O', 'O', 'O']
# > <ipython-input-107-2a21800d1e6c>(3)<module>()
# -> for t in tags:
# (Pdb)  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-107-2a21800d1e6c> in <module>
#       1 import pdb
#       2 for i,tags in enumerate(reg_test_pred_bio):
# ----> 3     for t in tags:
#       4         if 'B' in t:
#       5             print(i)
#
# <ipython-input-107-2a21800d1e6c> in <module>
#       1 import pdb
#       2 for i,tags in enumerate(reg_test_pred_bio):
# ----> 3     for t in tags:
#       4         if 'B' in t:
#       5             print(i)
#
# ~/miniconda3/envs/fastai/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/miniconda3/envs/fastai/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:

# %%
print("Number of test sentences: ", len(test_data))
print("sanity check: ", len(reg_test_pred_ibo))
print(len(reg_test_pred_ibo[0]))
print(reg_test_pred_ibo[0])
# Out:
# Number of test sentences:  3683
# sanity check:  3683
# 12
# ['O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O']

# %%
test_sent0 = test_data[0]
print(len(test_sent0))
print(test_sent0)
# Out:
# 12
# [['SOCCER', 'NN', 'I-NP'], ['-', ':', 'O'], ['JAPAN', 'NNP', 'I-NP'], ['GET', 'VB', 'I-VP'], ['LUCKY', 'NNP', 'I-NP'], ['WIN', 'NNP', 'I-NP'], [',', ',', 'O'], ['CHINA', 'NNP', 'I-NP'], ['IN', 'IN', 'I-PP'], ['SURPRISE', 'DT', 'I-NP'], ['DEFEAT', 'NN', 'I-NP'], ['.', '.', 'O']]

# %%
data_converter.add_column([test_sent0], [reg_test_pred_ibo[0]])
# Out:
# [[['SOCCER', 'NN', 'I-NP', 'O'],
#   ['-', ':', 'O', 'O'],
#   ['JAPAN', 'NNP', 'I-NP', 'I-LOC'],
#   ['GET', 'VB', 'I-VP', 'O'],
#   ['LUCKY', 'NNP', 'I-NP', 'O'],
#   ['WIN', 'NNP', 'I-NP', 'O'],
#   [',', ',', 'O', 'O'],
#   ['CHINA', 'NNP', 'I-NP', 'I-LOC'],
#   ['IN', 'IN', 'I-PP', 'O'],
#   ['SURPRISE', 'DT', 'I-NP', 'O'],
#   ['DEFEAT', 'NN', 'I-NP', 'O'],
#   ['.', '.', 'O', 'O']]]

# %%
# Let's add the predicted labels for all words
augmented = data_converter.add_column(test_data, reg_test_pred_ibo)
print("Sanity check: ", len(augmented))
augmented[0]
# Out:
# Sanity check:  3683
# [['SOCCER', 'NN', 'I-NP', 'O'],
#  ['-', ':', 'O', 'O'],
#  ['JAPAN', 'NNP', 'I-NP', 'I-LOC'],
#  ['GET', 'VB', 'I-VP', 'O'],
#  ['LUCKY', 'NNP', 'I-NP', 'O'],
#  ['WIN', 'NNP', 'I-NP', 'O'],
#  [',', ',', 'O', 'O'],
#  ['CHINA', 'NNP', 'I-NP', 'I-LOC'],
#  ['IN', 'IN', 'I-PP', 'O'],
#  ['SURPRISE', 'DT', 'I-NP', 'O'],
#  ['DEFEAT', 'NN', 'I-NP', 'O'],
#  ['.', '.', 'O', 'O']]

# %%
# write to a file
_ = data_converter.conll_to_data_stream(augmented, write_to_file='./pred_crf_c1:0.8_c2:0.9.txt');
